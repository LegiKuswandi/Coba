# %%
# pip install pandas

# %%
# pip install seaborn

# %%
# display
# %matplotlib inline  
# numerik
import numpy as np 
# analisis
import pandas as pd 
# plot
import matplotlib.pyplot as plt  
# visualisasi
import seaborn as sns

# %% [markdown]
# ##TARGET
# -DATA MULAI DARI 2017 (df daging_sapi mulainya dari 2017)
# -HAPUS SATUAN, KARENA SEMUA SATUAN DALAM "TON"
# -HAPUS JENIS_PRODUKSI, INSTEAD, UBAH JUMLAH_PRODUKSI JADI "NAMA_BAHAN" (CONTOH daging_ayam)
# -SATUKAN SELURUH "NAMA_BAHAN" DALAM 1 DF

# %%
#panggil dataset daging_ayam
df = pd.read_csv("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\dagingayam.csv")

#hapus satuan dan jenis_produksi
del df['satuan']
del df['jenis_produksi']

#rename
df = df.rename(columns={'jumlah_produksi': 'daging_ayam'})

#hapus data dibawah tahun 2017
df = df.loc[df['tahun'] >= 2017]

df.to_csv(("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\dagingayam.csv"), index=False)


df.head(500)

# %%
#panggil dataset daging_babi
df2 = pd.read_csv("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\dagingbabi.csv")

#hapus satuan dan jenis_produksi
del df2['satuan']
del df2['jenis_produksi']

#rename
df2 = df2.rename(columns={'jumlah_produksi': 'daging_babi'})

#hapus data dibawah tahun 2017
df2 = df2.loc[df2['tahun'] >= 2017]

df2.to_csv(("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\dagingbabi.csv"), index=False)

# Menggabungkan DataFrame df dan df2 
dfm = df.merge(df2[['kode_kabupaten_kota', 'tahun', 'daging_babi']], on=['kode_kabupaten_kota', 'tahun'], how='left')

dfm.to_csv(("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\all.csv"), index=False)


dfm.head(500)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    109             32    JAWA BARAT                 3204
# 1    110             32    JAWA BARAT                 3217
# 2    111             32    JAWA BARAT                 3216
# 3    112             32    JAWA BARAT                 3201
# 4    113             32    JAWA BARAT                 3207
# ..   ...            ...           ...                  ...
# 157  266             32    JAWA BARAT                 3275
# 158  267             32    JAWA BARAT                 3276
# 159  268             32    JAWA BARAT                 3277
# 160  269             32    JAWA BARAT                 3278
# 161  270             32    JAWA BARAT                 3279
#
#          nama_kabupaten_kota  daging_ayam  tahun  daging_babi
# 0          KABUPATEN BANDUNG        32324   2017            0
# 1    KABUPATEN BANDUNG BARAT        34275   2017            0
# 2           KABUPATEN BEKASI         9829   2017            6
# ...

# %%
#panggil dataset daging_domba
df3 = pd.read_csv("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\dagingdomba.csv")

#hapus satuan dan jenis_produksi
del df3['satuan']
del df3['jenis_produksi']

#rename
df3 = df3.rename(columns={'jumlah_produksi': 'daging_domba'})

#hapus data dibawah tahun 2017
df3 = df3.loc[df3['tahun'] >= 2017]

df3.to_csv(("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\dagingdomba.csv"), index=False)

# Menggabungkan DataFrame df dan df3 
dfm = dfm.merge(df3[['kode_kabupaten_kota', 'tahun', 'daging_domba']], on=['kode_kabupaten_kota', 'tahun'], how='left')

dfm.to_csv(("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\all.csv"), index=False)


dfm.head(500)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    109             32    JAWA BARAT                 3204
# 1    110             32    JAWA BARAT                 3217
# 2    111             32    JAWA BARAT                 3216
# 3    112             32    JAWA BARAT                 3201
# 4    113             32    JAWA BARAT                 3207
# ..   ...            ...           ...                  ...
# 157  266             32    JAWA BARAT                 3275
# 158  267             32    JAWA BARAT                 3276
# 159  268             32    JAWA BARAT                 3277
# 160  269             32    JAWA BARAT                 3278
# 161  270             32    JAWA BARAT                 3279
#
#          nama_kabupaten_kota  daging_ayam  tahun  daging_babi  daging_domba
# 0          KABUPATEN BANDUNG        32324   2017            0           826
# 1    KABUPATEN BANDUNG BARAT        34275   2017            0          2043
# ...

# %%
#panggil dataset daging_kelinci
df4 = pd.read_csv("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\dagingkelinci.csv")

#hapus satuan dan jenis_produksi
del df4['satuan']
del df4['jenis_produksi']

#rename
df4 = df4.rename(columns={'jumlah_produksi': 'daging_kelinci'})

#hapus data dibawah tahun 2017
df4 = df4.loc[df4['tahun'] >= 2017]

df4.to_csv(("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\dagingkelinci.csv"), index=False)

# Menggabungkan DataFrame df dan df4 
dfm = dfm.merge(df4[['kode_kabupaten_kota', 'tahun', 'daging_kelinci']], on=['kode_kabupaten_kota', 'tahun'], how='left')

dfm.to_csv(("C:\\Users\\USER\\OneDrive\\Documents\\catatan kuliah\\SEMESTER 5 (UPI)\\MATERI KULIAH\\Data Mining And Warehouse Praktikum\\tugas\\dataset_kelompok\\coba\\dataset_kelompok\\all.csv"), index=False)


dfm.head(500)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    109             32    JAWA BARAT                 3204
# 1    110             32    JAWA BARAT                 3217
# 2    111             32    JAWA BARAT                 3216
# 3    112             32    JAWA BARAT                 3201
# 4    113             32    JAWA BARAT                 3207
# ..   ...            ...           ...                  ...
# 157  266             32    JAWA BARAT                 3275
# 158  267             32    JAWA BARAT                 3276
# 159  268             32    JAWA BARAT                 3277
# 160  269             32    JAWA BARAT                 3278
# 161  270             32    JAWA BARAT                 3279
#
#          nama_kabupaten_kota  daging_ayam  tahun  daging_babi  daging_domba  \
# 0          KABUPATEN BANDUNG        32324   2017            0           826
# 1    KABUPATEN BANDUNG BARAT        34275   2017            0          2043
# ...
