# %% [markdown]
# ### KELOMPOK 7 EDA Pangan di Jawa Barat

# %%
# display
# %matplotlib inline
# numerik
import numpy as np
# analisis
import pandas as pd
# plot
import matplotlib.pyplot as plt
# visualisasi
import seaborn as sns

# %% [markdown]
# 1. MOHAMMAD FARIDZ FATHIN (2202680)
# 2. MUHAMMAD ISHAQ MAULANA
# 3. LEGI KUSWANDI
# 4. SHIDIQ ARIFIN SUDRAJAT (2202152)
# 5. CAHAYA AULIA FIRDAUSYAH
# 6. KELVIN JULIAN PUTRA (2205101)

# %% [markdown]
# IMPORT DATASET

# %%
ayam = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/dagingayam.csv'
babi = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/dagingbabi.csv'
domba = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/dagingdomba.csv'
kelinci = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/dagingkelinci.csv'
sapi = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/dagingsapi.csv'
kubis = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/kubis.csv'
pengeluaran = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/pengeluaran.csv'
susu_sapi = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/susu%20sapi.csv'
tuna = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/tuna.csv'
agama = 'https://raw.githubusercontent.com/LegiKuswandi/Coba/main/dataset_kelompok/agama.csv'
dfayam = pd.read_csv(ayam)
dfbabi = pd.read_csv(babi)
dfdomba = pd.read_csv(domba)
dfkelinci = pd.read_csv(kelinci)
dfsapi = pd.read_csv(sapi)
dfkubis = pd.read_csv(kubis)
dfsusu_sapi = pd.read_csv(susu_sapi)
dftuna = pd.read_dftuna = pd.read_csv(tuna)
dfpengeluaran = pd.read_csv(pengeluaran)
dfagama = pd.read_csv(agama)

dfayam
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3204
# 1      2             32    JAWA BARAT                 3217
# 2      3             32    JAWA BARAT                 3216
# 3      4             32    JAWA BARAT                 3201
# 4      5             32    JAWA BARAT                 3207
# ..   ...            ...           ...                  ...
# 265  266             32    JAWA BARAT                 3275
# 266  267             32    JAWA BARAT                 3276
# 267  268             32    JAWA BARAT                 3277
# 268  269             32    JAWA BARAT                 3278
# 269  270             32    JAWA BARAT                 3279
#
#          nama_kabupaten_kota  jumlah_produksi satuan  tahun jenis_produksi
# 0          KABUPATEN BANDUNG            12450    TON   2013    daging ayam
# 1    KABUPATEN BANDUNG BARAT            20721    TON   2013    daging ayam
# ...

# %% [markdown]
# ### PRAPROSES

# %% [markdown]
# Hapus satuan dan jenis_produksi, mengganti nama kolom jumlah_produksi dan menghapus data dibawah tahun 2017 pada tabel ayam

# %%
#hapus satuan dan jenis_produksi
del dfayam['satuan']
del dfayam['jenis_produksi']

#rename
dfayam = dfayam.rename(columns={'jumlah_produksi': 'daging_ayam'})

#hapus data dibawah tahun 2017
dfayam = dfayam.loc[dfayam['tahun'] >= 2017]

dfayam.head(10)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 108  109             32    JAWA BARAT                 3204
# 109  110             32    JAWA BARAT                 3217
# 110  111             32    JAWA BARAT                 3216
# 111  112             32    JAWA BARAT                 3201
# 112  113             32    JAWA BARAT                 3207
# 113  114             32    JAWA BARAT                 3203
# 114  115             32    JAWA BARAT                 3209
# 115  116             32    JAWA BARAT                 3205
# 116  117             32    JAWA BARAT                 3212
# 117  118             32    JAWA BARAT                 3215
#
#          nama_kabupaten_kota  daging_ayam  tahun
# 108        KABUPATEN BANDUNG        32324   2017
# 109  KABUPATEN BANDUNG BARAT        34275   2017
# 110         KABUPATEN BEKASI         9829   2017
# 111          KABUPATEN BOGOR       151368   2017
# 112         KABUPATEN CIAMIS       116049   2017
# ...

# %% [markdown]
# Hapus satuan dan jenis_produksi, mengganti nama kolom jumlah_produksi dan menghapus data dibawah tahun 2017 pada tabel babi

# %%
#hapus satuan dan jenis_produksi
del dfbabi['satuan']
del dfbabi['jenis_produksi']

#rename
dfbabi = dfbabi.rename(columns={'jumlah_produksi': 'daging_babi'})

#hapus data dibawah tahun 2017
dfbabi = dfbabi.loc[dfbabi['tahun'] >= 2017]

dfbabi.head(15)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 108  109             32    JAWA BARAT                 3204
# 109  110             32    JAWA BARAT                 3217
# 110  111             32    JAWA BARAT                 3216
# 111  112             32    JAWA BARAT                 3201
# 112  113             32    JAWA BARAT                 3207
# 113  114             32    JAWA BARAT                 3203
# 114  115             32    JAWA BARAT                 3209
# 115  116             32    JAWA BARAT                 3205
# 116  117             32    JAWA BARAT                 3212
# 117  118             32    JAWA BARAT                 3215
# 118  119             32    JAWA BARAT                 3208
# 119  120             32    JAWA BARAT                 3210
# 120  121             32    JAWA BARAT                 3218
# 121  122             32    JAWA BARAT                 3214
# 122  123             32    JAWA BARAT                 3213
#
# ...

# %% [markdown]
# Hapus satuan dan jenis_produksi, mengganti nama kolom jumlah_produksi dan menghapus data dibawah tahun 2017 pada tabel domba

# %%
#hapus satuan dan jenis_produksi
del dfdomba['satuan']
del dfdomba['jenis_produksi']

#rename
dfdomba = dfdomba.rename(columns={'jumlah_produksi': 'daging_domba'})

#hapus data dibawah tahun 2017
dfdomba = dfdomba.loc[dfdomba['tahun'] >= 2017]

dfdomba.head(10)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 108  109             32    JAWA BARAT                 3204
# 109  110             32    JAWA BARAT                 3217
# 110  111             32    JAWA BARAT                 3216
# 111  112             32    JAWA BARAT                 3201
# 112  113             32    JAWA BARAT                 3207
# 113  114             32    JAWA BARAT                 3203
# 114  115             32    JAWA BARAT                 3209
# 115  116             32    JAWA BARAT                 3205
# 116  117             32    JAWA BARAT                 3212
# 117  118             32    JAWA BARAT                 3215
#
#          nama_kabupaten_kota  daging_domba  tahun
# 108        KABUPATEN BANDUNG           826   2017
# 109  KABUPATEN BANDUNG BARAT          2043   2017
# 110         KABUPATEN BEKASI           629   2017
# 111          KABUPATEN BOGOR         10056   2017
# 112         KABUPATEN CIAMIS           452   2017
# ...

# %% [markdown]
# Hapus satuan dan jenis_produksi, mengganti nama kolom jumlah_produksi dan menghapus data dibawah tahun 2017 pada tabel kelinci

# %%
#hapus satuan dan jenis_produksi
del dfkelinci['satuan']
del dfkelinci['jenis_produksi']

#rename
dfkelinci = dfkelinci.rename(columns={'jumlah_produksi': 'daging_kelinci'})

#hapus data dibawah tahun 2017
dfkelinci = dfkelinci.loc[dfkelinci['tahun'] >= 2017]

dfkelinci.head(10)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 108  109             32    JAWA BARAT                 3204
# 109  110             32    JAWA BARAT                 3217
# 110  111             32    JAWA BARAT                 3216
# 111  112             32    JAWA BARAT                 3201
# 112  113             32    JAWA BARAT                 3207
# 113  114             32    JAWA BARAT                 3203
# 114  115             32    JAWA BARAT                 3209
# 115  116             32    JAWA BARAT                 3205
# 116  117             32    JAWA BARAT                 3212
# 117  118             32    JAWA BARAT                 3215
#
#          nama_kabupaten_kota  daging_kelinci  tahun
# 108        KABUPATEN BANDUNG             320   2017
# 109  KABUPATEN BANDUNG BARAT             990   2017
# 110         KABUPATEN BEKASI               0   2017
# 111          KABUPATEN BOGOR             250   2017
# 112         KABUPATEN CIAMIS              80   2017
# ...

# %% [markdown]
# Hapus satuan dan jenis_produksi, mengganti nama kolom jumlah_produksi dan menghapus data dibawah tahun 2017 pada tabel susu sapi

# %%
#hapus satuan dan jenis_produksi
del dfsusu_sapi['satuan']
del dfsusu_sapi['jenis_produksi']

#rename
dfsusu_sapi = dfsusu_sapi.rename(columns={'jumlah_produksi': 'susu_sapi'})

#hapus data dibawah tahun 2017
dfsusu_sapi = dfsusu_sapi.loc[dfsusu_sapi['tahun'] >= 2017]

dfsusu_sapi.head(10)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 108  109             32    JAWA BARAT                 3204
# 109  110             32    JAWA BARAT                 3217
# 110  111             32    JAWA BARAT                 3216
# 111  112             32    JAWA BARAT                 3201
# 112  113             32    JAWA BARAT                 3207
# 113  114             32    JAWA BARAT                 3203
# 114  115             32    JAWA BARAT                 3209
# 115  116             32    JAWA BARAT                 3205
# 116  117             32    JAWA BARAT                 3212
# 117  118             32    JAWA BARAT                 3215
#
#          nama_kabupaten_kota  susu_sapi  tahun
# 108        KABUPATEN BANDUNG      81884   2017
# 109  KABUPATEN BANDUNG BARAT     119767   2017
# 110         KABUPATEN BEKASI         71   2017
# 111          KABUPATEN BOGOR      19010   2017
# 112         KABUPATEN CIAMIS        245   2017
# ...

# %% [markdown]
# Hapus satuan dan jenis_produksi, mengganti nama kolom jumlah_produksi dan menghapus data dibawah tahun 2017 pada tabel tuna

# %%
#hapus satuan dan jenis_produksi
del dftuna['satuan']
del dftuna['jenis_produksi']

#rename
dftuna = dftuna.rename(columns={'produksi_perikanan': 'tuna'})
dftuna['tuna'] = dftuna['tuna'].round(0).astype(int)

#hapus data dibawah tahun 2017
dftuna = dftuna.loc[dftuna['tahun'] >= 2017]

dftuna.head(10)
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201
# 1   2             32    JAWA BARAT                 3202
# 2   3             32    JAWA BARAT                 3203
# 3   4             32    JAWA BARAT                 3204
# 4   5             32    JAWA BARAT                 3205
# 5   6             32    JAWA BARAT                 3206
# 6   7             32    JAWA BARAT                 3207
# 7   8             32    JAWA BARAT                 3208
# 8   9             32    JAWA BARAT                 3209
# 9  10             32    JAWA BARAT                 3210
#
#      nama_kabupaten_kota  tuna  tahun
# 0        KABUPATEN BOGOR     0   2018
# 1     KABUPATEN SUKABUMI   161   2018
# 2      KABUPATEN CIANJUR     0   2018
# 3      KABUPATEN BANDUNG     0   2018
# 4        KABUPATEN GARUT  5750   2018
# 5  KABUPATEN TASIKMALAYA     0   2018
# 6       KABUPATEN CIAMIS     0   2018
# ...

# %% [markdown]
# Hapus satuan dan jenis_produksi, mengganti nama kolom jumlah_produksi dan menghapus data dibawah tahun 2017 pada tabel padi

# %%
#hapus satuan dan jenis_produksi
del dfkubis['satuan']
del dfkubis['jenis_produksi']

#rename
dfkubis = dfkubis.rename(columns={'produksi_kubis': 'kubis'})

#hapus data dibawah tahun 2017
dfkubis = dfkubis.loc[dfkubis['tahun'] >= 2017]

dfkubis.head(15)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 108  109             32    JAWA BARAT                 3201
# 109  110             32    JAWA BARAT                 3202
# 110  111             32    JAWA BARAT                 3203
# 111  112             32    JAWA BARAT                 3204
# 112  113             32    JAWA BARAT                 3205
# 113  114             32    JAWA BARAT                 3206
# 114  115             32    JAWA BARAT                 3207
# 115  116             32    JAWA BARAT                 3208
# 116  117             32    JAWA BARAT                 3209
# 117  118             32    JAWA BARAT                 3210
# 118  119             32    JAWA BARAT                 3211
# 119  120             32    JAWA BARAT                 3212
# 120  121             32    JAWA BARAT                 3213
# 121  122             32    JAWA BARAT                 3214
# 122  123             32    JAWA BARAT                 3215
#
# ...

# %% [markdown]
# Hapus satuan dan jenis_produksi, mengganti nama kolom jumlah_produksi dan menghapus data dibawah tahun 2017 pada tabel sapi

# %%
# #hapus satuan dan jenis_produksi
del dfsapi['satuan']
del dfsapi['jenis_produksi']

#rename
dfsapi = dfsapi.rename(columns={'jumlah_produksi': 'daging_sapi'})

#hapus data dibawah tahun 2017
dfsapi = dfsapi.loc[dfsapi['tahun'] >= 2017]

dfsapi.head(10)
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3204
# 1   2             32    JAWA BARAT                 3217
# 2   3             32    JAWA BARAT                 3216
# 3   4             32    JAWA BARAT                 3201
# 4   5             32    JAWA BARAT                 3207
# 5   6             32    JAWA BARAT                 3203
# 6   7             32    JAWA BARAT                 3209
# 7   8             32    JAWA BARAT                 3205
# 8   9             32    JAWA BARAT                 3212
# 9  10             32    JAWA BARAT                 3215
#
#        nama_kabupaten_kota  daging_sapi  tahun
# 0        KABUPATEN BANDUNG      2285082   2017
# 1  KABUPATEN BANDUNG BARAT      3256863   2017
# 2         KABUPATEN BEKASI      2214551   2017
# 3          KABUPATEN BOGOR      9969490   2017
# 4         KABUPATEN CIAMIS      1156358   2017
# 5        KABUPATEN CIANJUR      1509880   2017
# ...

# %% [markdown]
# Mengganti satuan pada tabel sapi, sebelumnya tabel sapi memiliki satuan kilogram sementara tabel yang lain memiliki satuan ton jadi disini kita memutuskan untuk menyamakan satuan nya menjadi ton.

# %%
def kg_to_ton(daging_sapi):
    return daging_sapi / 1000

dfsapi['daging_sapi'] = dfsapi['daging_sapi'].apply(kg_to_ton)
dfsapi['daging_sapi'] = dfsapi['daging_sapi'].round(0).astype(int)

dfsapi.head(10)
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3204
# 1   2             32    JAWA BARAT                 3217
# 2   3             32    JAWA BARAT                 3216
# 3   4             32    JAWA BARAT                 3201
# 4   5             32    JAWA BARAT                 3207
# 5   6             32    JAWA BARAT                 3203
# 6   7             32    JAWA BARAT                 3209
# 7   8             32    JAWA BARAT                 3205
# 8   9             32    JAWA BARAT                 3212
# 9  10             32    JAWA BARAT                 3215
#
#        nama_kabupaten_kota  daging_sapi  tahun
# 0        KABUPATEN BANDUNG         2285   2017
# 1  KABUPATEN BANDUNG BARAT         3257   2017
# 2         KABUPATEN BEKASI         2215   2017
# 3          KABUPATEN BOGOR         9969   2017
# 4         KABUPATEN CIAMIS         1156   2017
# 5        KABUPATEN CIANJUR         1510   2017
# ...

# %%
dfagama
# Out:
#         id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0        1             32    JAWA BARAT                 3201
# 1        2             32    JAWA BARAT                 3201
# 2        3             32    JAWA BARAT                 3201
# 3        4             32    JAWA BARAT                 3201
# 4        5             32    JAWA BARAT                 3201
# ...    ...            ...           ...                  ...
# 1696  1697             32    JAWA BARAT                 3279
# 1697  1698             32    JAWA BARAT                 3279
# 1698  1699             32    JAWA BARAT                 3279
# 1699  1700             32    JAWA BARAT                 3279
# 1700  1701             32    JAWA BARAT                 3279
#
#      nama_kabupaten_kota             agama  jumlah_penduduk satuan  tahun
# 0        KABUPATEN BOGOR             ISLAM          3633669   JIWA   2013
# 1        KABUPATEN BOGOR           KRISTEN            70820   JIWA   2013
# ...

# %%
dfagama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1701 entries, 0 to 1700
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1701 non-null   int64
#  1   kode_provinsi        1701 non-null   int64
#  2   nama_provinsi        1701 non-null   object
#  3   kode_kabupaten_kota  1701 non-null   int64
#  4   nama_kabupaten_kota  1701 non-null   object
#  5   agama                1701 non-null   object
#  6   jumlah_penduduk      1701 non-null   int64
#  7   satuan               1701 non-null   object
#  8   tahun                1701 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 119.7+ KB

# %% [markdown]
# Mengubah dfagama agar memiliki atribut kolom nama - nama dari agama, yang sebelumnya jadi isi dari kolom agama.

# %%
# Pivot tabel untuk mengubah agama menjadi kolom baru
dfagama_baru = dfagama.pivot_table(index=['kode_provinsi', 'nama_provinsi', 'kode_kabupaten_kota', 'nama_kabupaten_kota', 'tahun'],
                               columns='agama', values='jumlah_penduduk', aggfunc='first')

# Reset indeks untuk menjadikan beberapa kolom sebagai indeks
dfagama_baru.reset_index(inplace=True)
dfagama_baru = dfagama_baru.loc[dfagama_baru['tahun']>=2017]
dfagama_baru = dfagama_baru.rename(columns={'agama': 'id'})
dfagama_baru.head(1000)
# Out:
# agama  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 4                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 5                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 6                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 7                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 8                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# ..               ...           ...                  ...                 ...
# 238               32    JAWA BARAT                 3279         KOTA BANJAR
# 239               32    JAWA BARAT                 3279         KOTA BANJAR
# 240               32    JAWA BARAT                 3279         KOTA BANJAR
# 241               32    JAWA BARAT                 3279         KOTA BANJAR
# 242               32    JAWA BARAT                 3279         KOTA BANJAR
#
# ...

# %%
dfagama_baru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135 entries, 4 to 242
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   kode_provinsi        135 non-null    int64
#  1   nama_provinsi        135 non-null    object
#  2   kode_kabupaten_kota  135 non-null    int64
#  3   nama_kabupaten_kota  135 non-null    object
#  4   tahun                135 non-null    int64
#  5   BUDHA                135 non-null    int64
#  6   HINDU                135 non-null    int64
#  7   ISLAM                135 non-null    int64
#  8   KATHOLIK             135 non-null    int64
#  9   KEPERCAYAAN LAIN     135 non-null    int64
#  10  KONGHUCHU            135 non-null    int64
#  11  KRISTEN              135 non-null    int64
# dtypes: int64(10), object(2)
# memory usage: 13.7+ KB

# %%
dfpengeluaran.info
# Out:
# <bound method DataFrame.info of       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 343  344             32    JAWA BARAT                 3275
# 344  345             32    JAWA BARAT                 3276
# 345  346             32    JAWA BARAT                 3277
# 346  347             32    JAWA BARAT                 3278
# 347  348             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_pengeluaran_per_kapita       satuan  tahun
# 0       KABUPATEN BOGOR                        8951.96  RIBU RUPIAH   2010
# 1    KABUPATEN SUKABUMI                        7658.57  RIBU RUPIAH   2010
# ...

# %% [markdown]
# Menghapus kolom satuan dalam dfpengeluaran

# %%
# #hapus satuan
del dfpengeluaran['satuan']

#hapus data dibawah tahun 2017
dfpengeluaran = dfpengeluaran.loc[dfpengeluaran['tahun'] >= 2017]

dfpengeluaran.head(10)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 186  187             32    JAWA BARAT                 3201
# 187  188             32    JAWA BARAT                 3202
# 188  189             32    JAWA BARAT                 3203
# 189  190             32    JAWA BARAT                 3204
# 190  191             32    JAWA BARAT                 3205
# 191  192             32    JAWA BARAT                 3206
# 192  193             32    JAWA BARAT                 3207
# 193  194             32    JAWA BARAT                 3208
# 194  195             32    JAWA BARAT                 3209
# 195  196             32    JAWA BARAT                 3210
#
#        nama_kabupaten_kota  jumlah_pengeluaran_per_kapita  tahun
# 186        KABUPATEN BOGOR                         9901.0   2017
# 187     KABUPATEN SUKABUMI                         8263.0   2017
# 188      KABUPATEN CIANJUR                         7300.0   2017
# ...

# %% [markdown]
# Karena tadi ada satuan ribu rupiah, tetapi tadi sudah kita hapus, jadi kita mengkalikan jumlah pengeluaran dengan 1000 agar menjadi jutaan

# %%
#mengubah satuan ribu rupiah jadi rupiah
def sejutain(jumlah_pengeluaran_per_kapita):
    return jumlah_pengeluaran_per_kapita * 1000

dfpengeluaran['jumlah_pengeluaran_per_kapita'] = dfpengeluaran['jumlah_pengeluaran_per_kapita'].apply(sejutain)

dfpengeluaran.head(1000)
# Out:
# C:\Users\Legi Kuswandi\AppData\Local\Temp\ipykernel_13244\3037846858.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfpengeluaran['jumlah_pengeluaran_per_kapita'] = dfpengeluaran['jumlah_pengeluaran_per_kapita'].apply(sejutain)
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 186  187             32    JAWA BARAT                 3201
# 187  188             32    JAWA BARAT                 3202
# 188  189             32    JAWA BARAT                 3203
# 189  190             32    JAWA BARAT                 3204
# 190  191             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 343  344             32    JAWA BARAT                 3275
# ...

# %%
#mengubah tipe data jumlah_pengeluaran_per_kapita
dfpengeluaran['jumlah_pengeluaran_per_kapita'] = dfpengeluaran['jumlah_pengeluaran_per_kapita'].round(0).astype(int)
# Out:
# C:\Users\Legi Kuswandi\AppData\Local\Temp\ipykernel_13244\545505362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfpengeluaran['jumlah_pengeluaran_per_kapita'] = dfpengeluaran['jumlah_pengeluaran_per_kapita'].round(0).astype(int)

# %%
dfpengeluaran.head(500)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 186  187             32    JAWA BARAT                 3201
# 187  188             32    JAWA BARAT                 3202
# 188  189             32    JAWA BARAT                 3203
# 189  190             32    JAWA BARAT                 3204
# 190  191             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 343  344             32    JAWA BARAT                 3275
# 344  345             32    JAWA BARAT                 3276
# 345  346             32    JAWA BARAT                 3277
# 346  347             32    JAWA BARAT                 3278
# 347  348             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_pengeluaran_per_kapita  tahun
# 186     KABUPATEN BOGOR                        9901000   2017
# 187  KABUPATEN SUKABUMI                        8263000   2017
# 188   KABUPATEN CIANJUR                        7300000   2017
# ...

# %% [markdown]
# Menyatukan semua datadrame

# %%
dfm = dfayam.merge(dfbabi[['kode_kabupaten_kota', 'tahun', 'daging_babi']], on=['kode_kabupaten_kota', 'tahun'], how='left')
dfm = dfm.merge(dfdomba[['kode_kabupaten_kota', 'tahun', 'daging_domba']], on=['kode_kabupaten_kota', 'tahun'], how='left')
dfm = dfm.merge(dfkelinci[['kode_kabupaten_kota', 'tahun', 'daging_kelinci']], on=['kode_kabupaten_kota', 'tahun'], how='left')
dfm = dfm.merge(dfsapi[['kode_kabupaten_kota', 'tahun', 'daging_sapi']], on=['kode_kabupaten_kota', 'tahun'], how='left')
dfm = dfm.merge(dfkubis[['kode_kabupaten_kota', 'tahun', 'kubis']], on=['kode_kabupaten_kota', 'tahun'], how='left')
dfm = dfm.merge(dfsusu_sapi[['kode_kabupaten_kota', 'tahun', 'susu_sapi']], on=['kode_kabupaten_kota', 'tahun'], how='left')
dfm = dfm.merge(dftuna[['kode_kabupaten_kota', 'tahun', 'tuna']], on=['kode_kabupaten_kota', 'tahun'], how='left')

# %% [markdown]
# Hanya mengambil data diatas tahun 2018 agar tidak ada data null

# %%
dfm = dfm.loc[dfm['tahun'] >= 2018]
dfm.head(500)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 27   136             32    JAWA BARAT                 3204
# 28   137             32    JAWA BARAT                 3217
# 29   138             32    JAWA BARAT                 3216
# 30   139             32    JAWA BARAT                 3201
# 31   140             32    JAWA BARAT                 3207
# ..   ...            ...           ...                  ...
# 157  266             32    JAWA BARAT                 3275
# 158  267             32    JAWA BARAT                 3276
# 159  268             32    JAWA BARAT                 3277
# 160  269             32    JAWA BARAT                 3278
# 161  270             32    JAWA BARAT                 3279
#
#          nama_kabupaten_kota  daging_ayam  tahun  daging_babi  daging_domba  \
# 27         KABUPATEN BANDUNG        20141   2018            0          1967
# 28   KABUPATEN BANDUNG BARAT        14995   2018            0          2059
# ...

# %%
dfm.isnull().sum()
# Out:
# id                      0
# kode_provinsi           0
# nama_provinsi           0
# kode_kabupaten_kota     0
# nama_kabupaten_kota     0
# daging_ayam             0
# tahun                   0
# daging_babi             0
# daging_domba            0
# daging_kelinci          0
# daging_sapi             0
# kubis                  27
# susu_sapi               0
# tuna                   27
# dtype: int64

# %%
dfagama_baru.head(10)
# Out:
# agama  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 4                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 5                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 6                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 7                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 8                 32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 13                32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 14                32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 15                32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 16                32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 17                32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
#
# agama  tahun  BUDHA  HINDU    ISLAM  KATHOLIK  KEPERCAYAAN LAIN  KONGHUCHU  \
# ...

# %% [markdown]
# Memasukan data pengeluaran dan agama ke data frame yang sudah di merge tadi

# %%
dfm = dfm.merge(dfpengeluaran[['kode_kabupaten_kota', 'tahun', 'jumlah_pengeluaran_per_kapita']], on=['kode_kabupaten_kota', 'tahun'], how='left')
dfm = dfm.merge(dfagama_baru[['kode_kabupaten_kota', 'tahun', 'ISLAM', 'KRISTEN', 'HINDU', 'BUDHA', 'KATHOLIK', 'KONGHUCHU', 'KEPERCAYAAN LAIN']], on=['kode_kabupaten_kota', 'tahun'], how='left')
dfm.head(500)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    136             32    JAWA BARAT                 3204
# 1    137             32    JAWA BARAT                 3217
# 2    138             32    JAWA BARAT                 3216
# 3    139             32    JAWA BARAT                 3201
# 4    140             32    JAWA BARAT                 3207
# ..   ...            ...           ...                  ...
# 130  266             32    JAWA BARAT                 3275
# 131  267             32    JAWA BARAT                 3276
# 132  268             32    JAWA BARAT                 3277
# 133  269             32    JAWA BARAT                 3278
# 134  270             32    JAWA BARAT                 3279
#
#          nama_kabupaten_kota  daging_ayam  tahun  daging_babi  daging_domba  \
# 0          KABUPATEN BANDUNG        20141   2018            0          1967
# 1    KABUPATEN BANDUNG BARAT        14995   2018            0          2059
# ...

# %% [markdown]
# Hanya mengambil data di bawah 2022 agar tidak ada data null

# %%
dfm = dfm.loc[(dfm['tahun'] >= 2018) & (dfm['tahun'] <= 2021)]
dfm.head(50)
# Out:
#      id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0   136             32    JAWA BARAT                 3204
# 1   137             32    JAWA BARAT                 3217
# 2   138             32    JAWA BARAT                 3216
# 3   139             32    JAWA BARAT                 3201
# 4   140             32    JAWA BARAT                 3207
# 5   141             32    JAWA BARAT                 3203
# 6   142             32    JAWA BARAT                 3209
# 7   143             32    JAWA BARAT                 3205
# 8   144             32    JAWA BARAT                 3212
# 9   145             32    JAWA BARAT                 3215
# 10  146             32    JAWA BARAT                 3208
# 11  147             32    JAWA BARAT                 3210
# 12  148             32    JAWA BARAT                 3218
# 13  149             32    JAWA BARAT                 3214
# 14  150             32    JAWA BARAT                 3213
# ...

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 0 to 107
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             108 non-null    int64
#  1   kode_provinsi                  108 non-null    int64
#  2   nama_provinsi                  108 non-null    object
#  3   kode_kabupaten_kota            108 non-null    int64
#  4   nama_kabupaten_kota            108 non-null    object
#  5   daging_ayam                    108 non-null    int64
#  6   tahun                          108 non-null    int64
#  7   daging_babi                    108 non-null    int64
#  8   daging_domba                   108 non-null    int64
#  9   daging_kelinci                 108 non-null    int64
#  10  daging_sapi                    108 non-null    int32
#  11  kubis                          108 non-null    float64
# ...

# %% [markdown]
# ### PROSES

# %% [markdown]
# #### Barplot untuk melihat rata-rata produksi daging per kota/kabupaten

# %%
dfp = dfm.groupby(['nama_kabupaten_kota'])[['daging_ayam', 'daging_babi', 'daging_domba', 'daging_kelinci', 'daging_sapi']].mean()
dfp.plot(kind='bar')
plt.title('Rata-rata Produksi Daging per Kota/Kabupaten')
plt.xlabel('Kota/Kabupaten')
plt.ylabel('Rata-rata Produksi')
plt.show()

# %% [markdown]
# Dapat kita lihat diatas kebanyakan kota/kabupaten di Jawa Barat rata-rata memproduksi daging ayam lebih banyak daripada daging lain dengan yang terbanyak adalah Kabupaten Bogor. Tetapi ada juga beberapa kota/kabupaten yang produksi sapinya lebih banyak daripada ayam seperti Kota Bandung dan Kota Bogor.

# %% [markdown]
# #### BARPLOT untuk melihat rata - rata dari produksi daging di jawa barat

# %%
variables_to_plot = ['daging_ayam', 'daging_babi', 'daging_domba', 'daging_kelinci', 'daging_sapi']

# Hitung rata-rata konsumsi daging untuk setiap variabel
mean_values = dfm[variables_to_plot].mean()

# Buat bar plot
plt.figure(figsize=(12, 6))
plt.bar(mean_values.index, mean_values)
plt.title('Rata-rata Produksi Daging')
plt.xlabel('Variabel Daging')
plt.ylabel('Rata-rata Produksi')
plt.xticks(rotation=45)  # Untuk memutar label sumbu x

# Tampilkan plot
plt.show()

# %% [markdown]
# Dapat kita lihat dari visualisasi data di atas rata - rata produksi daging ayam jauh lebih tinggi dari pada produksi daging yang lain, disusul daging sapi, daging domba, daging kelinci dan daging babi.

# %% [markdown]
# #### Line Plot Pengeluaran Per Kapita Per tahun

# %%
# Membuat line plot menggunakan Seaborn
plt.figure(figsize=(8, 6))
sns.lineplot(data=dfm, x='tahun', y='jumlah_pengeluaran_per_kapita', marker='o', color='b');
plt.title('Pengeluaran Per Kapita per Tahun')
plt.xlabel('Tahun')
plt.ylabel('Pengeluaran Per Kapita')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dapat Kita lihat di line plot diatas pengeluaran per kapita sempat naik di tahun 2019, tetapi dapat kita lihat dikarenakan di 2020 ada covid 19 pengeluaran per kapita menurun.

# %% [markdown]
# #### Line Plot Memvisualisasikan data produksi daging Per tahun

# %%
# Membuat line plot menggunakan Seaborn
plt.figure(figsize=(8, 6))
totalll = dfm['daging_babi'] + dfm['daging_ayam'] + dfm['daging_kelinci'] + dfm['daging_domba'] + dfm['daging_sapi']
sns.lineplot(data=dfm, x='tahun', y=totalll, marker='o', color='b')

plt.title('Produksi Daging Per tahun')
plt.xlabel('Tahun')
plt.ylabel('Produksi Daging')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dapat Kita lihat di line plot diatas produksi daging naik di tahun 2019, tetapi dapat kita lihat dikarenakan di 2020 ada covid 19 produksi daging menurun.

# %% [markdown]
# #### BARPLOT untuk melihat produksi Ikan Tuna Kabupaten/Kota

# %%
dfm = dfm.sort_values(by='tuna', ascending=False)

# Membuat bar plot horizontal
plt.figure(figsize=(10, 6))  # Mengatur ukuran plot
plt.barh(dfm['nama_kabupaten_kota'], dfm['tuna'], color='skyblue')
plt.xlabel('Produksi Ikan Tuna')  # Label sumbu x
plt.ylabel('Nama Kabupaten/Kota')  # Label sumbu y
plt.title('Produksi Ikan Tuna per Kabupaten/Kota')  # Judul plot

# Menampilkan plot
plt.show()

# %% [markdown]
# Setelah memvisualisasikan data dengan menggunakan barplot dapat kita lihat produksi ikan tuna paling banyak di daerah - daerah yang mempunyai wilayah laut seperti Kabupaten Garut, Kabupaten Sukabumi, Kota Banjar dan Kabupaten Sumedang. Tetapi ada sesuatu sangat menarik yang di visualisasi data di atas, kota Bandung yang tidak mempunyai wilayah laut ternyata juga memproduksi ikan Tuna bahkan jumlahnya di atas Kabupaten Sumedang.

# %% [markdown]
# #### Line Plot Memvisualisasikan data produksi daging Babi Kabupaten/Kota

# %%
dfm = dfm.sort_values(by='daging_babi', ascending=False)

# Membuat bar plot horizontal
plt.figure(figsize=(10, 6))  # Mengatur ukuran plot
plt.barh(dfm['nama_kabupaten_kota'], dfm['daging_babi'], color='skyblue')
plt.xlabel('Produksi Daging Babi')  # Label sumbu x
plt.ylabel('Nama Kabupaten/Kota')  # Label sumbu y
plt.title('Produksi Daaging Babi per Kabupaten/Kota')  # Judul plot

# Menampilkan plot
plt.show()

# %% [markdown]
# #### Boxplot distribusi pengeluaran per kapita

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='jumlah_pengeluaran_per_kapita', data=dfm)
plt.xlabel('Pengeluaran per Kapita')
plt.title('Distribusi Pengeluaran per Kapita')
plt.show()
